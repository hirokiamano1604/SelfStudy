# %% [markdown]
# # Efficient Frontier Part 2

# %%
# %load_ext autoreload
# %autoreload 2
import edhec_risk_kit as erk
# %matplotlib inline

ind = erk.get_ind_returns()
er = erk.annualize_rets(ind["1996":"2000"],12)
cov = ind["1996":"2000"].cov()
# Out:
# /Applications/SelfStudy/PythonForPortfolio/Module 2/edhec_risk_kit.py:48: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   ind = pd.read_csv("../data/ind30_m_vw_rets.csv", header = 0, index_col = 0, parse_dates= True) /100

# %%
def portfolio_return(weights, returns):
    """Weights → Returns"""
    return weights.T @ returns

def portfolio_vol(weights,covmat):
    """Weights → Vol"""
    return (weights.T @ covmat @ weights)**0.5

# %%
l = ["Food", "Beer" , "Smoke" , "Coal"]
er[l]
# Out:
# Food     0.116799
# Beer     0.141126
# Smoke    0.107830
# Coal     0.414689
# dtype: float64

# %%
cov.loc[l,l]
# Out:
#            Food      Beer     Smoke      Coal
# Food   0.002609  0.002379  0.002061  0.000027
# Beer   0.002379  0.005264  0.001359  0.001728
# Smoke  0.002061  0.001359  0.008349 -0.000733
# Coal   0.000027  0.001728 -0.000733  0.018641

# %%
import numpy as np
weights = np.repeat(1/4,4)
erk.portfolio_return(weights, er[l])
# Out:
# 0.19511097196038385

# %%
erk.portfolio_vol(weights, cov.loc[l,l])
# Out:
# 0.05505919577643704

# %% [markdown]
# ## 2 Assets Frontier

# %%
l = ["Games", "Fin"]

# %%
n_points = 20
weights = [np.array([w,1-w]) for w in np.linspace(0,1,n_points)]
weights
# Out:
# [array([0., 1.]),
#  array([0.05263158, 0.94736842]),
#  array([0.10526316, 0.89473684]),
#  array([0.15789474, 0.84210526]),
#  array([0.21052632, 0.78947368]),
#  array([0.26315789, 0.73684211]),
#  array([0.31578947, 0.68421053]),
#  array([0.36842105, 0.63157895]),
#  array([0.42105263, 0.57894737]),
#  array([0.47368421, 0.52631579]),
#  array([0.52631579, 0.47368421]),
#  array([0.57894737, 0.42105263]),
#  array([0.63157895, 0.36842105]),
#  array([0.68421053, 0.31578947]),
#  array([0.73684211, 0.26315789]),
#  array([0.78947368, 0.21052632]),
#  array([0.84210526, 0.15789474]),
#  array([0.89473684, 0.10526316]),
#  array([0.94736842, 0.05263158]),
#  array([1., 0.])]

# %%
import pandas as pd
rets = [erk.portfolio_return(w,er[l]) for w in weights]
vols = [erk.portfolio_vol(w,cov.loc[l,l]) for w in weights]
ef = pd.DataFrame({"R": rets, "Vol" : vols})
ef.plot.scatter(x = "Vol",y = "R")
fig = ax.get_figure()               # check it's a Figure
plt.show()

# %%
l = ["Fin", "Beer"]
erk.plot_ef2(25, er[l], cov.loc[l,l], style = "--")
plt.show()
