# %% [markdown]
# # Present Value of Liabilities and Funding Ratio
# THe present value of a set of liabilitoes $L$ where each liability $L_i$ is due at time $t_i$ is given by:
# $$PV(L) = \sum_{i=1}^{k} B(t_i) L_i$$
# where $B(t_i)$ is the price of a pure discount bond that pays 1 dollar at time $t_i$
#
# If we assume that the yield curve is flat and the annual rate of interest is $r$, then $B(t)$ is given by
# $$B(t) = \frac{1}{(1+r)^t}$$
# $$\therefore B(t) (1+r)^t = 1$$

# %%
import pandas as pd 
import numpy as np
import edhec_risk_kit as erk

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def discount(t,r):
    """ 
    Compute the price of a pure discount bond that pays a dollar at time t, given interest rate r
    """
    return (1+r)**(-t)

# %%
discount(10,0.03)
# Out:
# 0.7440939148967249

# %%
def pv(l, r):
    """
    Computes the present Value of a sequence of liabilities
    l is indexed by the time, and the values are the amounts of each liability
    returns the present value of the sequence
    """
    dates = l.index
    discounts = discount(dates, r)
    return (discounts*l).sum()

# %%
liabilities = pd.Series(data=[1,1.5,2,2.5], index = [3,3.5,4,4.5])

# %%
liabilities
# Out:
# 3.0    1.0
# 3.5    1.5
# 4.0    2.0
# 4.5    2.5
# dtype: float64

# %%
pv(liabilities, 0.03)
# Out:
# 6.233320315080045

# %%
liabilities.sum()
# Out:
# 7.0

# %%
def funding_ratio(assets, liabilities, r):
    """
    Computes the funding ratio of some assets given liabilities and interest rate    
    """
    return assets/pv(liabilities,r)

# %%
funding_ratio(5,liabilities,0.03)
# Out:
# 0.8021407126958777

# %%
funding_ratio(5,liabilities,0.02)
# Out:
# 0.7720304366941648

# %%
funding_ratio(5,liabilities,0.05)
# Out:
# 0.8649082768407927

# %%
import ipywidgets as widgets
from IPython.display import display
# %matplotlib inline

def show_funding_ratio(assets, r):
    fr = funding_ratio(assets, liabilities, r)
    print(f'funding_ratio:{fr*100:.2f}')

controls = widgets.interactive(show_funding_ratio,
                               assets = widgets.IntSlider(min=1, max=10, step=1, value=5),
                               r = (0, 0.20, 0.01)
                               )
display(controls)
# Out:
# interactive(children=(IntSlider(value=5, description='assets', max=10, min=1), FloatSlider(value=0.1, descript…
